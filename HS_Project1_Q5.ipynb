# %%
import csv
import os
import pandas as pd

baseline_filepath = "ea1141_baseline_demog_derived_ birth-year-removed.csv"

baseline_df = pd.read_csv(baseline_filepath)

baseline_df.head()
# Out:
#   ENROLLING_IN_DE CURRENT_IN_DE  RANDOM_DATE_YYYY  RANDOM_DATE_DAYS  DOB_DAYS  \
# 0        72FC1C8A      72FC1C8A              2017                 0    -20478
# 1        A7A3CBF0      A7A3CBF0              2017                 0    -20672
# 2        72FC1C8A      72FC1C8A              2017                 0    -21055
# 3        E93E9C9A      E93E9C9A              2017                 0    -20247
# 4        1B8DD944      1B8DD944              2017                 0    -22339
#
#    ARM  AGE  SEX  RACE  ETHNICITY  ...  GENETIC_OTHER_SPECIFY  FAM_HISTORY_BC  \
# 0    1   56    1     5          2  ...                     .N               0
# 1    2   56    1     5          2  ...                     .N               0
# 2    1   57    1     5          2  ...                     .N               1
# 3    2   55    1     5          2  ...                     .N               1
# 4    2   61    1     5          2  ...                     .N               1
#
# ...

# %%
clean_baseline_df=baseline_df.drop(["ENROLLING_IN_DE", "CURRENT_IN_DE", "RANDOM_DATE_YYYY", "RANDOM_DATE_DAYS", "ARM", "INELIG_REASON", "INSURANCE_FULL", "INSURANCE_COLLAPSE", "PRIOR_HORMONEUSE_1", "PRIOR_HORMONEUSE_2", "PRIOR_HORMONEUSE_3", "PRIOR_HORMONEUSE_4", "DATE_LAST_CLINEXAM_YYYY", "DATE_LAST_CLINEXAM_DAYS", "PRIOR_BENIGN_BIOP", "PRIOR_BENIGN_BIOP_TOT", "PRIOR_BIOP_ADH", "PRIOR_BIOP_ALH", "PRIOR_BIOP_LCIS" ], axis=1)
clean_baseline_df.head()

# Clean for ineligible patients
# Out:
#    DOB_DAYS  AGE  SEX  RACE  ETHNICITY  ELIG  PRIOR_BREAST_DENSITY  \
# 0    -20478   56    1     5          2     1                     3
# 1    -20672   56    1     5          2     1                     3
# 2    -21055   57    1     5          2     1                     3
# 3    -20247   55    1     5          2     1                     3
# 4    -22339   61    1     5          2     1                     3
#
#   AGE_FIRSTMENSTRUAL LASTMENSTRUAL NUM_LIVE_BIRTHS  ... GENETIC_HNPCC  \
# 0                 12             5               2  ...             0
# 1                 16             3               3  ...             0
# 2                 12             1               3  ...             0
# 3                 11             1               2  ...             0
# 4                 15             2               0  ...             0
#
#   GENETIC_PTEN  GENETIC_P53  GENETIC_OTHER  GENETIC_OTHER_SPECIFY  \
# 0            0            0              0                     .N
# ...

# %%
six_month_filepath = "ea1141_6month_fup.csv"

six_month_df = pd.read_csv(six_month_filepath)

six_month_df.head()
# Out:
#   FUP_6MO FUP_6MO_REASON FUP_6MO_STATUS FUP_6MO_DATE_YYYY FUP_6MO_DATE_DAYS  \
# 0       1              N              1              2017               213
# 1       1              N              1              2017               182
# 2       3              6              3                 N                 N
# 3       3              4              3                 N                 N
# 4       1              N              1              2017               163
#
#   FUP_6MO_DATERA_YYYY FUP_6MO_DATERA_DAYS FUP_6MO_CANCER  \
# 0                2017                 213              0
# 1                2017                 182              0
# 2                2018                 393              0
# 3                2018                 288              0
# 4                2017                 154              0
#
#   FUP_6MO_CANCERDATE_YYYY FUP_6MO_CANCERDATE_DAYS FUP_6MO_CANCERDETECT  \
# 0                       N                       N                    N
# ...

# %%
# Clean for if the patient followed up after 6 months

clean_six_month_df = six_month_df.drop(["FUP_6MO_REASON", "FUP_6MO_DATE_YYYY", "FUP_6MO_DATE_DAYS", "FUP_6MO_DATERA_YYYY", "FUP_6MO_DATERA_DAYS", "FUP_6MO_CANCERBIOPSY"], axis=1)
clean_six_month_df.head()
# Out:
#   FUP_6MO FUP_6MO_STATUS FUP_6MO_CANCER FUP_6MO_CANCERDATE_YYYY  \
# 0       1              1              0                       N
# 1       1              1              0                       N
# 2       3              3              0                       N
# 3       3              3              0                       N
# 4       1              1              0                       N
#
#   FUP_6MO_CANCERDATE_DAYS FUP_6MO_CANCERDETECT  SUBJECT_DE
# 0                       N                    N        2922
# 1                       N                    N       24530
# 2                       N                    N       55074
# 3                       N                    N       64074
# 4                       N                    N       67998

# %%
twelve_month_filepath = "ea1141_12month_fup.csv"
twelve_month_df = pd.read_csv(twelve_month_filepath)
twelve_month_df.head()
# Out:
#   FUP_12MO FUP_12MO_REASON FUP_12MO_STATUS FUP_12MO_DATE_YYYY  \
# 0        1               N               1               2018
# 1        1               N               1               2018
# 2        1               N               1               2018
# 3        1               N               1               2018
# 4        1               N               1               2018
#
#   FUP_12MO_DATE_DAYS FUP_12MO_DATERA_YYYY FUP_12MO_DATERA_DAYS  \
# 0                360                 2018                  360
# 1                377                 2018                  377
# 2                392                 2018                  392
# 3                376                 2018                  376
# 4                318                 2018                  318
#
#   FUP_12MO_DATELASTRA_YYYY FUP_12MO_DATELASTRA_DAYS FUP_12MO_CANCER  ...  \
# 0                     2017                      213               0  ...
# ...

# %%
clean_twelve_month_df = twelve_month_df.drop(["FUP_12MO_REASON", "FUP_12MO_DATE_YYYY", "FUP_12MO_DATE_DAYS", "FUP_12MO_DATERA_YYYY", "FUP_12MO_DATERA_DAYS", "FUP_12MO_DATELASTRA_YYYY", "FUP_12MO_DATELASTRA_DAYS", "FUP_12MO_330DAYS", "FUP_12MO_330DAYSYR0", "TOMO_YR1_DATE_YYYY", "TOMO_YR1_DATE_DAYS", "MRI_YR1_DATE_YYYY", "MRI_YR1_DATE_DAYS"], axis=1)
clean_twelve_month_df.head()

# Clean for removing row
# Out:
#   FUP_12MO FUP_12MO_STATUS FUP_12MO_CANCER FUP_12MO_CANCERDATE_YYYY  \
# 0        1               1               0                        N
# 1        1               1               0                        N
# 2        1               1               0                        N
# 3        1               1               0                        N
# 4        1               1               0                        N
#
#   FUP_12MO_CANCERDATE_DAYS FUP_12MO_CANCERDETECT FUP_12MO_CANCERBIOPSY  \
# 0                        N                     N                     N
# 1                        N                     N                     N
# 2                        N                     N                     N
# 3                        N                     N                     N
# 4                        N                     N                     N
#
#   TOMO_YR1 TOMO_YR1_REASON TOMO_YR1_REASON_SIMPLE MRI_YR1 MRI_YR1_REASON  \
# ...

# %%
risk_model_filepath = "ea1141_bcsc_risk_model.csv"
risk_model_df = pd.read_csv(risk_model_filepath)
risk_model_df.head()
# Out:
#    BCSC_AGE  BCSC_RACEETHN  BCSC_FIRSTDEGREE  BCSC_PBB  BCSC_DENSITY  \
# 0        56              1                 0         2             3
# 1        56              1                 0         2             3
# 2        57              1                 0         2             3
# 3        55              1                 1         2             3
# 4        61              1                 1         3             2
#
#      BCSC_5YEAR   BCSC_10YEAR BCSC_REASON  BCSC_PRIORHISTORYBC  \
# 0  1.6054408579  3.4028961682           N                    0
# 1  1.6054408579  3.4028961682           N                    0
# 2  1.6650002216  3.5024061127           N                    0
# 3  2.3315944418  4.9508877628           N                    0
# 4  2.8749400017  5.8284810188           N                    0
#
#    BCSC_FIRSTDEGREEOVARIAN  SUBJECT_DE
# 0                        0        2922
# 1                        0       24530
# 2                        0       55074
# ...

# %%
clean_risk_model_df = risk_model_df.drop(["BCSC_REASON", "BCSC_5YEAR", "BCSC_10YEAR", "BCSC_AGE", "BCSC_RACEETHN", "BCSC_PBB", "BCSC_DENSITY", "BCSC_REASON", "BCSC_PRIORHISTORYBC"], axis=1)
clean_risk_model_df.head()
# Out:
#    BCSC_FIRSTDEGREE  BCSC_FIRSTDEGREEOVARIAN  SUBJECT_DE
# 0                 0                        0        2922
# 1                 0                        0       24530
# 2                 0                        0       55074
# 3                 1                        0       64074
# 4                 1                        0       67998

# %%
# Merge all of the above datasets and then delete the ineligible patients and the patients that didn't follow up

first_merge_df = pd.merge(clean_baseline_df,clean_six_month_df, how="outer", on=["SUBJECT_DE"])
second_merge_df = pd.merge(first_merge_df, clean_twelve_month_df, how='outer', on=["SUBJECT_DE"])
second_merge_df.head()

final_df = second_merge_df.loc[(second_merge_df["ELIG"] == "1")|(second_merge_df["FUP_6MO"] == "1")|(second_merge_df["FUP_6MO"] == "2")|(second_merge_df["FUP_6MO"] == "3")]
final_df.sample(10)
# Out:
#      DOB_DAYS  AGE  SEX  RACE  ETHNICITY  ELIG  PRIOR_BREAST_DENSITY  \
# 335    -16931   46    1     5          1     1                     3
# 146    -15333   41    1    98         98     1                     3
# 318    -24629   67    1     5          2     1                     3
# 195    -17563   48    1     5          2     1                     3
# 414    -20569   56    1     5         99     1                     3
# 170    -16236   44    1     5          2     1                     3
# 78     -20918   57    1     5          2     1                     3
# 396    -16339   44    1     5          2     1                     4
# 182    -24121   66    1     5          2     1                     3
# 428    -23925   65    1     5          2     1                     3
#
#     AGE_FIRSTMENSTRUAL LASTMENSTRUAL NUM_LIVE_BIRTHS  ...  \
# 335                 12             5               3  ...
# 146                 12             1               1  ...
# ...

# %%
#!pip install pyreadr

import pyreadr

df = pyreadr.read_r('48_-_breast_cancer_data.RData')['out']
# Out:
# ...
#   Obtaining dependency information for pyreadr from https://files.pythonhosted.org/packages/d3/42/a1b4e94d8ad328a8fba6052adb26097333ee58572e88eaa5154f69b823a7/pyreadr-0.5.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.3 MB 435.7 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.3 MB 770.8 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.3 MB 1.4 MB/s eta 0:00:01
#    --------------------- ------------------ 0.7/1.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 5.7 MB/s eta 0:00:00
# ...

# %%
df.sample(10)
# Out:
#       der_ordinal_v1a  der_days_fu der_deadbinary der_dead30 der_mv der_ICU  \
# 382                 0         90.0             No         No     No      No
# 1111                0         90.0             No         No     No      No
# 825                 1         42.0             No         No     No      No
# 298                 0         14.0             No         No     No      No
# 705                 0        180.0             No         No     No      No
# 831                 1        180.0             No         No     No      No
# 232                 1         42.0             No         No     No      No
# 567                 0        365.0             No         No     No      No
# 308                 0         21.0             No         No     No      No
# 1304                4          6.0            Yes        Yes    Yes     Yes
#
#      der_hosp der_AKI_comp der_MOF_comp der_coinfection_any  ...  \
# 382        No           No           No                  No  ...
# ...

# %%
ans = df.loc[df['der_smoking2'] == 'Never']
len(ans)
# Out:
# 911
