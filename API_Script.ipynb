# %%
import pandas as pd
import requests
from pprint import pprint
from bs4 import BeautifulSoup

# %%
# Set the API base URL
base_url = "https://health.gov/myhealthfinder/api/v3/myhealthfinder.json?"
age = 60
sex = "female"
category = "All"

# Creating endpoint URL
url = f"{base_url}age={age}&sex={sex}&category={category}"
print(url)
# Out:
# https://health.gov/myhealthfinder/api/v3/myhealthfinder.json?age=60&sex=female&category=All

# %%
#JSON
cancer_response = requests.get(url).json()
pprint(cancer_response)
# Out:
# {'Result': {'AboutTheseResults': '<p>The MyHealthfinder recommendations come '
#                                  'from the U.S. Preventive Services Task Force '
#                                  '(USPSTF), the CDC Advisory Committee on '
#                                  'Immunization Practices (ACIP), and the '
#                                  'Health Resources and Services Administration '
#                                  '(HRSA) as advised by organizations including '
#                                  'the American Academy of Pediatrics (through '
#                                  'the Bright Futures cooperative agreement) '
#                                  'and the National Academies of Sciences, '
#                                  'Engineering, and Medicine (formerly the '
#                                  'Institute of Medicine). The Affordable Care '
#                                  'Act requires most insurance plans to cover '
# ...

# %%
cancer_response.keys()
# Out:
# dict_keys(['Result'])

# %%
cancer_response["Result"].keys()
# Out:
# dict_keys(['Error', 'Total', 'Query', 'Language', 'TakeAction', 'AboutTheseResults', 'MyHFHeading', 'Resources'])

# %%
cancer_response["Result"]["Resources"].keys()
# Out:
# dict_keys(['all'])

# %%
cancer_response["Result"]["Resources"]["all"].keys()
# Out:
# dict_keys(['Resource'])

# %%
cancer_response["Result"]["Resources"]["all"]["Resource"][4]
# Out:
# {'Type': 'Topic',
#  'Id': '514',
#  'Title': 'Get Tested for Breast Cancer',
#  'TranslationId': '514',
#  'TranslationTitle': '',
#  'Categories': 'Breast and Ovarian Cancer, Screening Tests',
#  'Populations': '',
#  'MyHFTitle': 'Get Tested for Breast Cancer',
#  'MyHFDescription': '<p>Get a mammogram every 2 years. (USPSTF)</p>\r\n',
#  'MyHFCategory': 'all',
#  'MyHFCategoryHeading': '<h2 class="all" >Doctors recommend that <span>all</span> women age <span>60</span>:</h2>',
#  'LastUpdate': '1657923500',
#  'ImageUrl': 'https://health.gov/sites/default/files/2022-07/gtfbc.jpg',
#  'ImageAlt': 'A woman talks to her health care provider.',
#  'AccessibleVersion': 'https://health.gov/myhealthfinder/health-conditions/cancer/get-tested-breast-cancer',
#  'RelatedItems': {'RelatedItem': [{'Type': 'Topic',
#     'Id': '531',
#     'Title': 'Get Screened',
#     'Url': 'https://health.gov/myhealthfinder/doctor-visits/screening-tests/get-screened'},
#    {'Type': 'Topic',
# ...

# %%
cancer_response["Result"]["Resources"]["all"]["Resource"][4].keys()
# Out:
# dict_keys(['Type', 'Id', 'Title', 'TranslationId', 'TranslationTitle', 'Categories', 'Populations', 'MyHFTitle', 'MyHFDescription', 'MyHFCategory', 'MyHFCategoryHeading', 'LastUpdate', 'ImageUrl', 'ImageAlt', 'AccessibleVersion', 'RelatedItems', 'Sections', 'MoreInfoItems', 'HealthfinderLogo', 'HealthfinderUrl'])

# %%
cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"].keys()
# Out:
# dict_keys(['section'])

# %% [markdown]
# ## Overview of Breast Cancer

# %%
cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][0]
# Out:
# {'Title': 'The Basics: Overview',
#  'Description': '',
# ...

# %%
cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][0].keys()
# Out:
# dict_keys(['Title', 'Description', 'Content'])

# %%
print(cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][0]["Title"])
# Out:
# The Basics: Overview

# %%
print(cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][0]["Content"])
# Out:
# <p><span><span><span><span><span><span><span>Breast cancer is one of the most common kinds of cancer in women. About 1 in 8 women&nbsp;in the United States will get breast cancer&nbsp;during her lifetime.&nbsp;</span></span></span></span></span></span></span></p>
#
# <p><span><span><span><span><span><span><span>The good news is that mammograms can help find breast cancer early — before it spreads to other parts of the body.&nbsp;Most&nbsp;women can survive breast cancer if it’s found and treated early.</span></span></span></span></span></span></span></p>
#
# <h4>How often should I get mammograms?</h4>
#
# <ul>
# 	<li>If you’re age 40 to 49, talk with your doctor about when to start getting mammograms and how often to get them</li>
# 	<li>If you’re age 50 to 74, get mammograms every 2 years</li>
# </ul>
#
# <h4>What is a mammogram?</h4>
#
# ...

# %%
soup = BeautifulSoup("""<li><span><span><span><span><span><span><span>Breast cancer is one of the most common kinds of cancer in women. About 1 in 8 women&nbsp;in the United States will get breast cancer&nbsp;during her lifetime.&nbsp;</span></span></span></span></span></span></span></li>

<li><span><span><span><span><span><span><span>The good news is that mammograms can help find breast cancer early — before it spreads to other parts of the body.&nbsp;Most&nbsp;women can survive breast cancer if it’s found and treated early.</span></span></span></span></span></span></span></li>

<li>How often should I get mammograms?</li>

<ul>
	<li>If you’re age 40 to 49, talk with your doctor about when to start getting mammograms and how often to get them</li>
	<li>If you’re age 50 to 74, get mammograms every 2 years</li>
</ul>

<li>What is a mammogram?</li>

<li><span><span><span><span><span><span><span>A mammogram is an x-ray picture of the breast. Mammograms use a very low level of x-rays, which are a type of radiation. The risk of harm from this radiation is very low.</span></span></span></span></span></span></span></li>

<li><span><span><span><span><span><span><span>Mammograms can be used to screen (test) for breast cancer in women with no signs or symptoms. They can also help doctors figure out if cancer is causing a particular symptom — like a&nbsp;lump&nbsp;or another change in the breast.</span></span></span></span></span></span></span></li>

<li><span><span><span><span><span><span><span>When you get a mammogram, a technician will place your breast on a platform and a plastic plate will press it flat to get a clear picture. This part of a mammogram can be uncomfortable, but it usually only lasts 15 to 20 seconds.</span></span></span></span></span></span></span></li>

<li><span><span><span><span><span><span><span>It takes about 20 minutes total to get mammograms.&nbsp; href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/www.womenshealth.gov/a-z-topics/mammograms?_label_=Learn+more+about+mammograms">Learn more about mammograms.&nbsp;</span></span></span></span></span></span></span></li>""", 'html.parser')

li_tags = soup.find_all('li')
for li in li_tags:
    print(li.get_text())
# Out:
# Breast cancer is one of the most common kinds of cancer in women. About 1 in 8 women in the United States will get breast cancer during her lifetime.
# The good news is that mammograms can help find breast cancer early — before it spreads to other parts of the body. Most women can survive breast cancer if it’s found and treated early.
# How often should I get mammograms?
# If you’re age 40 to 49, talk with your doctor about when to start getting mammograms and how often to get them
# If you’re age 50 to 74, get mammograms every 2 years
# What is a mammogram?
# A mammogram is an x-ray picture of the breast. Mammograms use a very low level of x-rays, which are a type of radiation. The risk of harm from this radiation is very low.
# Mammograms can be used to screen (test) for breast cancer in women with no signs or symptoms. They can also help doctors figure out if cancer is causing a particular symptom — like a lump or another change in the breast.
# ...

# %% [markdown]
# ## Basics of Breast Cancer

# %%
cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][1]
# Out:
# {'Title': 'The Basics: Breast Cancer',
#  'Description': '',
# ...

# %%
print(cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][1]["Title"])
# Out:
# The Basics: Breast Cancer

# %%
print(cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][1]["Content"])
# Out:
# <h4>What is breast cancer?</h4>
#
# <p><span><span><span><span><span><span><span>Breast cancer is cancer that forms in breast tissue. Like all cancers, breast cancer can spread to other parts of the body.</span></span></span></span></span></span></span></p>
#
# <p><span><span><span><span><span><span><span>Talk with your doctor or nurse if you notice any of these changes:</span></span></span></span></span></span></span></p>
#
# <ul>
# 	<li><span><span>A lump or an area that feels very firm in the breast or armpit</span></span></li>
# 	<li><span><span>A change in the size, shape, or feel of the breast</span></span></li>
# 	<li><span><span>Fluid (called discharge) coming out of a nipple</span></span></li>
# 	<li><span><span>Skin on the breast that is itchy, red, flaky, or dimpled</span></span></li>
# </ul>
#
# ...

# %%
soup = BeautifulSoup("""<p>What is breast cancer?</p>

<p><span><span><span><span><span><span><span>Breast cancer is cancer that forms in breast tissue. Like all cancers, breast cancer can spread to other parts of the body.</span></span></span></span></span></span></span></p>

<p><span><span><span><span><span><span><span>Talk with your doctor or nurse if you notice any of these changes:</span></span></span></span></span></span></span></p>

<ul>
	<p><span><span>A lump or an area that feels very firm in the breast or armpit</span></span></p>
	<p><span><span>A change in the size, shape, or feel of the breast</span></span></p>
	<p><span><span>Fluid (called discharge) coming out of a nipple</span></span></p>
	<p><span><span>Skin on the breast that is itchy, red, flaky, or dimpled</span></span></p>
</ul>

<p><span><span><span><span><span><span><span> href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/www.cancer.gov/types/breast?_label_=Learn+more+about+breast+cancer">Learn more about breast cancer.</span></span></span></span></span></span></span></p>

<p>What if the doctor finds something in my breast?</p>

<p><span><span><span><span><span><span><span>Mammograms let the doctor or nurse look for lumps or other changes inside your breasts that you can’t feel from the outside. If your doctor finds&nbsp;a lump or another change in your breast tissue,&nbsp;you may need other tests to find out if it’s cancer or not.</span></span></span></span></span></span></span></p>

<p><span><span><span><span><span><span><span>The doctor or nurse may take a small bit of tissue from the breast for testing. This procedure is called a biopsy.</span></span></span></span></span></span></span></p>
""", 'html.parser')

p_tags = soup.find_all('p')
for p in p_tags:
    print(p.get_text())
# Out:
# What is breast cancer?
# Breast cancer is cancer that forms in breast tissue. Like all cancers, breast cancer can spread to other parts of the body.
# Talk with your doctor or nurse if you notice any of these changes:
# A lump or an area that feels very firm in the breast or armpit
# A change in the size, shape, or feel of the breast
# Fluid (called discharge) coming out of a nipple
# Skin on the breast that is itchy, red, flaky, or dimpled
#  href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/www.cancer.gov/types/breast?_label_=Learn+more+about+breast+cancer">Learn more about breast cancer.
# What if the doctor finds something in my breast?
# Mammograms let the doctor or nurse look for lumps or other changes inside your breasts that you can’t feel from the outside. If your doctor finds a lump or another change in your breast tissue, you may need other tests to find out if it’s cancer or not.
# ...

# %% [markdown]
# ## Next Steps

# %%
cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][2]
# Out:
# {'Title': 'Take Action: See Your Doctor',
#  'Description': '',
# ...

# %%
print(cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][2]["Title"])
# Out:
# Take Action: See Your Doctor

# %%
print(cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][2]["Content"])
# Out:
# <p>Talk with your doctor about when and how often to get mammograms.</p>
#
# <h4>Ask the doctor about your risk for breast cancer.<strong>&nbsp;</strong></h4>
#
# <p><span><span><span><span><span><span><span><a href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/health.gov/myhealthfinder/topics/doctor-visits/talking-with-the-doctor/mammograms-questions-for-the-doctor?_label_=Use+these+questions+to+start+a+conversation+with+your+doctor+about%26nbsp%3Bmammograms">Use these questions to start a conversation with your doctor about&nbsp;mammograms</a>. You can also ask about ways you may be able to lower your risk for breast cancer.</span></span></span></span></span></span></span></p>
#
# ...

# %%
soup = BeautifulSoup("""<p>Talk with your doctor about when and how often to get mammograms.</p>

<p>Ask the doctor about your risk for breast cancer.<strong>&nbsp;</strong></p>

<p><span><span><span><span><span><span><span> href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/health.gov/myhealthfinder/topics/doctor-visits/talking-with-the-doctor/mammograms-questions-for-the-doctor?_label_=Use+these+questions+to+start+a+conversation+with+your+doctor+about%26nbsp%3Bmammograms">Use these questions to start a conversation with your doctor about&nbsp;mammograms. You can also ask about ways you may be able to lower your risk for breast cancer.</span></span></span></span></span></span></span></p>

<p><span><span><span><span><span><span><span> href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/health.gov/myhealthfinder/topics/health-conditions/cancer/talk-doctor-if-breast-or-ovarian-cancer-runs-your-family?_label_=Tell+your+doctor+if+breast+or+ovarian+cancer+runs+in+your+family">Tell your doctor if breast or ovarian cancer runs in your family — that may increase your risk for developing these and other types of cancer. You can  href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/health.gov/myhealthfinder/topics/doctor-visits/talking-doctor/genetic-testing-learn-about-your-risk-breast-and-ovarian-cancer-questions-doctor?_label_=use+these+questions+to+talk+with+your+doctor+about+genetic%26nbsp%3Btesting+for+breast+or+ovarian+cancer">use these questions to talk with your doctor about genetic&nbsp;testing for breast or ovarian cancer.&nbsp;</span></span></span></span></span></span></span></p>

<p>Together, you and your doctor can decide what’s best for you.</p>""", 'html.parser')

p_tags = soup.find_all('p')
for p in p_tags:
    print(p.get_text())
# Out:
# Talk with your doctor about when and how often to get mammograms.
# Ask the doctor about your risk for breast cancer.
#  href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/health.gov/myhealthfinder/topics/doctor-visits/talking-with-the-doctor/mammograms-questions-for-the-doctor?_label_=Use+these+questions+to+start+a+conversation+with+your+doctor+about%26nbsp%3Bmammograms">Use these questions to start a conversation with your doctor about mammograms. You can also ask about ways you may be able to lower your risk for breast cancer.
# ...

# %% [markdown]
# ## Cost And Insurance

# %%
cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][3]
# Out:
# {'Title': 'Take Action: Cost and Insurance',
#  'Description': '',
# ...

# %%
print(cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][3]["Title"])
# Out:
# Take Action: Cost and Insurance

# %%
print(cancer_response["Result"]["Resources"]["all"]["Resource"][4]["Sections"]["section"][3]["Content"])
# Out:
# <h4>What about cost?</h4>
#
# <p><span><span><span><span><span><span><span>Under the&nbsp;Affordable Care Act, insurance plans must cover mammograms for women over age 40. Depending on your insurance plan, you may be able to get mammograms at no cost to you. Check with your insurance company to find out more. </span></span></span></span></span></span></span></p>
#
# <p><span><span><span><span><span><span><span>Medicare also covers mammograms for women over age 40 at no cost. <a href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/http/www.medicare.gov/coverage/mammograms.html?_label_=Find+out+about+Medicare+coverage+for+mammograms">Find out about Medicare coverage for mammograms</a>.</span></span></span></span></span></span></span></p>
#
# ...

# %%
soup = BeautifulSoup("""<h4>What about cost?</h4>

<p><span><span><span><span><span><span><span>Under the&nbsp;Affordable Care Act, insurance plans must cover mammograms for women over age 40. Depending on your insurance plan, you may be able to get mammograms at no cost to you. Check with your insurance company to find out more. </span></span></span></span></span></span></span></p>

<p><span><span><span><span><span><span><span>Medicare also covers mammograms for women over age 40 at no cost. href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/http/www.medicare.gov/coverage/mammograms.html?_label_=Find+out+about+Medicare+coverage+for+mammograms">Find out about Medicare coverage for mammograms.</span></span></span></span></span></span></span></p>

<p><span><span><span><span><span><span><span>If you don’t have insurance, you can still get mammograms. href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/www.cdc.gov/cancer/nbccedp/screenings.htm?_label_=Find+a+program+near+you+that+offers+free+or+low-cost+mammograms">Find a program near you that offers free or low-cost mammograms.</span></span></span></span></span></span></span></p>

<p><span><span><span><span><span><span><span>To learn more, check out these resources:</span></span></span></span></span></span></span></p>

<ul>
	<p><span><span><span> href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/www.healthcare.gov/preventive-care-women/?_label_=Free+preventive+care%26nbsp%3Bfor+women+covered+by+the+Affordable+Care+Act">Free preventive care&nbsp;for women covered by the Affordable Care Act</span></span></span></p>
	<p><span><span><span> href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/www.healthcare.gov/health-care-law-protections/?_label_=How+the+Affordable+Care+Act+protects+you">How the Affordable Care Act protects you &nbsp;&nbsp;</span></span></span></p>
	<p> href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/marketplace.cms.gov/technical-assistance-resources/c2c-roadmap.pdf?_label_=Understanding+your+health+insurance+and+how+to+use+it+%5BPDF+-+698%26nbsp%3BKB%5D" id="anch_81">Understanding your health insurance and how to use it [PDF - 698&nbsp;KB]</p>
</ul>""", 'html.parser')

p_tags = soup.find_all('p')
for p in p_tags:
    print(p.get_text())
# Out:
# Under the Affordable Care Act, insurance plans must cover mammograms for women over age 40. Depending on your insurance plan, you may be able to get mammograms at no cost to you. Check with your insurance company to find out more.
# Medicare also covers mammograms for women over age 40 at no cost. href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/http/www.medicare.gov/coverage/mammograms.html?_label_=Find+out+about+Medicare+coverage+for+mammograms">Find out about Medicare coverage for mammograms.
# If you don’t have insurance, you can still get mammograms. href="https://health.gov/myhealthfinder/api/outlink/myhealthfinder.json/https/www.cdc.gov/cancer/nbccedp/screenings.htm?_label_=Find+a+program+near+you+that+offers+free+or+low-cost+mammograms">Find a program near you that offers free or low-cost mammograms.
# To learn more, check out these resources:
# ...

# %% [markdown]
# ## Analysis
#
# The objective of this API was to retrieve information about breast cancer and the next steps. The API was filtered for females only, with age group around 60 Years Old since the dataset for this project reflects these filters. The API was retrieved from health.gov/myhealthfinder and only focuses on United States since the dataset only covers United States. This API states that breast cancer is one of the most common kinds of cancer in women. About 1 in 8 women in the United States will get breast cancer during her lifetime. Furthermore, breast cancer is a cancer that forms in breast tissue and like all cancers, it can spread to other parts of the body. The API further explains to talk with your doctor or nurse if the female notices any of these changes: A lump or an area that feels very firm in the breast or armpit, A change in the size, shape, or feel of the breast, Fluid (called discharge) coming out of a nipple, Skin on the breast that is itchy, red, flaky, or dimpled. Moreover, mammograms let the doctor or nurse look for lumps or other changes inside the breasts that can’t be felt from the outside. If the doctor finds a lump or another change in the breast tissue, other tests may be needed to find out if it’s cancer or not. The doctor or nurse may take a small bit of tissue from the breast for testing. This procedure is called a biopsy. Lastly, under the Affordable Care Act, insurance plans must cover mammograms for women over age 40. Depending on the insurance plan, mammograms might be free of cost. Check with the insurance company to find out more. However, this only relates to individuals in the United States.
